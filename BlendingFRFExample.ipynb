# %% [markdown]
# <a href="https://colab.research.google.com/github/jonghyunharrylee/blendbathyERDC/blob/main/BlendingFRFExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook serves as an example of how to use the `BlendingBathyERDC` package and also can reproduce results presented in the paper:
#
# "Lee et al., Blending Bathymetry: Combination of Parametric Beach Tool and Celerity data sets for real-time bathymetry estimation"

# %%
# !git clone https://github.com/jonghyunharrylee/blendbathyERDC.git
# %cd blendbathyERDC
# Out:
# Cloning into 'blendbathyERDC'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 86 (delta 29), reused 50 (delta 13), pack-reused 0
# Receiving objects: 100% (86/86), 3.84 MiB | 6.61 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# /content/blendbathyERDC/blendbathyERDC

# %% [markdown]
# Note that in the current version, variables are read from pre-defined file names for development purposes, for example, 03272017cbathyv2_k.mat for frequency dependent wave number data $k_{f_B}$.

# %%
import os

# %%
import numpy as np
import scipy as sp
print('numpy version:',np.__version__,'\nscipy version:',sp.__version__)
# Out:
# numpy version: 1.23.5
# scipy version: 1.11.2

# %%
import bathyblendingERDC as bathyinv

# %%
# use_testdata: 0 (default) => 03272017, 1 => 11222017, 2 => 10062019
#params = {'use_testdata':0,'cbathy_dir':'./cbathy','pbt_dir':'./pbt','survey_dir':'./survey'}
params = {'use_testdata':1,'cbathy_dir':'./cbathy','pbt_dir':'./pbt','survey_dir':'./survey'}
#params = {'use_testdata':2,'cbathy_dir':'./cbathy','pbt_dir':'./pbt','survey_dir':'./survey'}
DuckBathy = bathyinv.BathyBlending(params=params)
blend_bathy = DuckBathy.blend()
# Out:
# ## 1. Initialize BathyBlending object
# 	- Loading Data...
# 	- tide is set to -0.433 m
# 	- # of wave observations from cBathy phase 1: 16337
# 	- screening the wave obs with skill parameter (skill > 0.500000)
# 	- screening the wave obs with lam1 parameter (lam1 > 10.000000)
# 	- screening the wave obs whose direct inversion of the depth h is between hfB_min 0.250000 and hfB_max 10.000000
# 		- perform direct, point/freq-wise bathy inversion from cBathy wave data using least square
# 	- # of wave observations used in this run after screening: 10950
# 	- (optional) perform direct, point-wise bathy inversion from cBathy wave data using least square with equal weights over the nfB freqs (similar to cBathy Phase 2)
# ## 2. Perform blending
# 	- observation error determined from cBathy Phase 1's kErr (obs_std_variable = True)
#
#  GN iteration 1, misfit: 7958.483045, reg: 0.000000, obj: 3979.241523, rmse :0.148145
#   inner cg iter 100, rel. res. (norm(res)/norm(g)): 2.2050e-05
#  - Linear Search, alpha : 0.725147, obj: 4020.811356, ierr: 0, nfunc: 14
#  GN iteration 2, misfit: 7703.638602, reg: 21.611324, obj: 3862.624963, rmse :0.146663
#  * misfit/tolerance discrency principle achieved
#
# #### Inversion completed in     7.509 secs          ####
# ## misfit: 7703.638602, reg: 21.611324, obj: 3862.624963
# ## init res. rmse: 0.148145
# ## final res. rmse: 0.146663
# #######################################################
#
#  - Blending results were corrected with tide and saved
# rmse blending, cbathy, prior : 0.527868, 1.532475, 0.572108
# bias blending, cbathy, prior : -0.150326, 0.843122, -0.231388

# %%
DuckBathy.plot_bathy()

# try below for the paper figure reproduction
if params['use_testdata'] == 0:
  DuckBathy.plot_bathy(yFRF=(-100.,1200),pierFRFhatch=(400,600))
if params['use_testdata'] == 1:
  DuckBathy.plot_bathy(yFRF=(-100.,1500),pierFRFhatch=(400,600))
if params['use_testdata'] == 2:
  DuckBathy.plot_bathy(yFRF=(-100.,1350),pierFRFhatch=(400,600))
#DuckBathy.plot_bathy(yFRF=(-500.,1500),pierFRFhatch=(400,600))
#DuckBathy.plot_bathy(yFRF=(-100.,1200),pierFRFhatch=(400,600))
#DuckBathy.plot_bathy(yFRF=(600.,1300),pierFRFhatch=(400,600))

# %%
DuckBathy.plot_bathy_error(pierFRF=None)

if params['use_testdata'] == 0:
  DuckBathy.plot_bathy_error(yFRF=(-500.,1200),pierFRFhatch=(400,600))
if params['use_testdata'] == 1:
  DuckBathy.plot_bathy_error(yFRF=(-500.,1500), pierFRFhatch=(400,600))
if params['use_testdata'] == 2:
  DuckBathy.plot_bathy_error(yFRF=(200.,1350), pierFRF=None, pierFRFhatch=None)

# %%
DuckBathy.plot_bathy_fitting()

# %%
DuckBathy.plot_bathy_fitting_all()

# %%
# DuckBathy.plot_transects([np.where(DuckBathy.y[0,:]==250)[0][0]])
if params['use_testdata'] == 2:
  DuckBathy.plot_transects([np.where(DuckBathy.y[0,:]==600)[0][0],np.where(DuckBathy.y[0,:]==950)[0][0]])
else:
  DuckBathy.plot_transects([np.where(DuckBathy.y[0,:]==250)[0][0],np.where(DuckBathy.y[0,:]==600)[0][0],np.where(DuckBathy.y[0,:]==950)[0][0]])

# %%
DuckBathy.plot_obs_fitting()

# %%
DuckBathy.plot_obslocs()

# %%
DuckBathy.plot_cbathy_errors()
